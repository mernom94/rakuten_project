# %%
import pandas as pd
df = pd.read_csv("../raw_data/x_test.csv", names=[
    "id", "designation", "description", "productid", "imageid"
])
df
# Out:
#             id                                        designation  \
# 0          NaN                                        designation
# 1      84916.0  Folkmanis Puppets - 2732 - Marionnette Et Théâ...
# 2      84917.0  Porte Flamme Gaxix - Flamebringer Gaxix - 136/...
# 3      84918.0                  Pompe de filtration Speck Badu 95
# 4      84919.0                        Robot de piscine électrique
# ...        ...                                                ...
# 13808  98723.0  Robe De Soutien De Sac De Soins De Les Suspend...
# 13809  98724.0          Livre De Phrases - Français ? Thaïlandais
# 13810  98725.0               Tifon1 200 M de Espa - Pompe piscine
# 13811  98726.0  Christmas Home Non Slip Door Floor Mats Hall R...
# 13812  98727.0  Suspension Cascade 6 Lumières Verra Noire Et C...
#
#                                              description   productid  \
# 0                                            description   productid
# ...

# %%
import pandas as pd
df = pd.read_csv("../raw_data/x_test.csv")
df

# %%
from sqlalchemy import create_engine, MetaData, Table, Column, Integer, String
import pandas as pd

df = pd.read_csv("../raw_data/x_test.csv", skiprows=1, names=[
    "id", "designation", "description", "productid", "imageid"
])

engine = create_engine("postgresql+psycopg2://rakutenadmin:rakutenadmin@localhost:5432/rakuten_db")
metadata = MetaData()

products = Table(
    "test", metadata,
    Column("id", Integer, primary_key=True),
    Column("designation", String),
    Column("description", String),
    Column("productid", String),
    Column("imageid", String),
)

metadata.create_all(engine)

df.to_sql("test", engine, if_exists="append", index=False)
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# File ~/rakuten/.venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py:2114, in Connection._exec_insertmany_context(self, dialect, context)
#    2113     else:
# -> 2114         dialect.do_execute(
#    2115             cursor,
#    2116             sub_stmt,
#    2117             sub_params,
#    2118             context,
#    2119         )
#    2121 except BaseException as e:
#
# File ~/rakuten/.venv/lib/python3.12/site-packages/sqlalchemy/engine/default.py:943, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     942 def do_execute(self, cursor, statement, parameters, context=None):
# --> 943     cursor.execute(statement, parameters)
#
# UniqueViolation: duplicate key value violates unique constraint "test_pkey"
# DETAIL:  Key (id)=(84916) already exists.
#
#
# ...
